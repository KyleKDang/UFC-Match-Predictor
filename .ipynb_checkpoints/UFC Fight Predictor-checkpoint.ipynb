# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/kyledang/Documents/Development/Projects/UFC-Fight-Predictor/ufc-master.csv')

# %%
columns_to_keep = [
    'RedFighter', 'BlueFighter', 'RedWins', 'RedLosses', 'RedCurrentWinStreak',
    'BlueWins', 'BlueLosses', 'BlueCurrentWinStreak',
    'RedAvgSigStrLanded', 'BlueAvgSigStrLanded',
    'RedAvgTDLanded', 'BlueAvgTDLanded',
    'Date', 'Location', 'Country', 'TitleBout', 'WeightClass',
    'RedOdds', 'BlueOdds', 'RedExpectedValue', 'BlueExpectedValue',
    'RedDecOdds', 'BlueDecOdds', 'RKOOdds', 'BKOOdds',
    'RedHeightCms', 'BlueHeightCms', 'RedWeightLbs', 'BlueWeightLbs',
    'RedReachCms', 'BlueReachCms', 'Winner'
]

data = data[columns_to_keep]
data
# Out:
#             RedFighter      BlueFighter  RedWins  RedLosses  \
# 0         Alex Pereira     Jamahal Hill        6          1
# 1          Zhang Weili      Yan Xiaonan        8          2
# 2       Justin Gaethje     Max Holloway        8          4
# 3     Charles Oliveira  Arman Tsarukyan       22          9
# 4            Bo Nickal    Cody Brundage        4          0
# ...                ...              ...      ...        ...
# 6183      Duane Ludwig    Darren Elkins        2          1
# 6184       John Howard   Daniel Roberts        3          0
# 6185    Brendan Schaub    Chase Gormley        0          1
# 6186       Mike Pierce    Julio Paulino        1          1
# 6187      Eric Schafer      Jason Brilz        3          3
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 0                       2         7           1                     4
# 1                       3         8           2                     2
# 2                       2        21           7                     2
# 3                       1         8           2                     3
# 4                       4         4           5                     2
# ...                   ...       ...         ...                   ...
# 6183                    0         0           0                     0
# 6184                    3         0           0                     0
# 6185                    0         0           1                     0
# 6186                    0         0           0                     0
# 6187                    0         2           1                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  BlueDecOdds  RKOOdds  \
# 0                 5.2300               7.1800  ...        650.0    110.0
# 1                 5.6600               4.9700  ...          NaN    140.0
# 2                 6.7800               7.1700  ...        250.0    150.0
# 3                 3.3900               3.7900  ...        330.0    550.0
# 4                 1.6400               1.6200  ...       3000.0    150.0
# ...                  ...                  ...  ...          ...      ...
# 6183             13.6667                  NaN  ...          NaN      NaN
# 6184             18.0000                  NaN  ...          NaN      NaN
# 6185             12.0000               8.0000  ...          NaN      NaN
# 6186             40.5000                  NaN  ...          NaN      NaN
# 6187             15.6667              31.6667  ...          NaN      NaN
#
#      BKOOdds RedHeightCms BlueHeightCms  RedWeightLbs BlueWeightLbs  \
# 0      200.0       193.04        193.04           205           205
# 1        NaN       162.56        165.10           115           115
# 2      550.0       180.34        180.34           155           145
# 3      130.0       177.80        170.18           155           155
# 4     1400.0       185.42        182.88           185           185
# ...      ...          ...           ...           ...           ...
# 6183     NaN       177.80        177.80           170           145
# 6184     NaN       170.18        177.80           170           170
# 6185     NaN       193.04        190.50           245           265
# 6186     NaN       172.72        182.88           170           170
# 6187     NaN       190.50        180.34           185           205
#
#       RedReachCms  BlueReachCms  Winner
# 0          200.66        200.66     Red
# 1          160.02        160.02     Red
# 2          177.80        175.26    Blue
# 3          187.96        182.88    Blue
# 4          193.04        182.88     Red
# ...           ...           ...     ...
# 6183       177.80        180.34    Blue
# 6184       180.34        187.96     Red
# 6185       198.12        196.00     Red
# 6186       177.80        185.42     Red
# 6187       190.50        180.34    Blue
#
# [6188 rows x 32 columns]

# %%
non_numeric_columns = data.select_dtypes(exclude=['number']).columns.tolist()
non_numeric_columns
# Out:
# ['RedFighter',
#  'BlueFighter',
#  'Date',
#  'Location',
#  'Country',
#  'TitleBout',
#  'WeightClass',
#  'Winner']

# %%
data['Date_code'] = data['Date'].astype('category').cat.codes
data['Location_code'] = data['Location'].astype('category').cat.codes
data['Country_code'] = data['Country'].astype('category').cat.codes
data['TitleBout_code'] = data['TitleBout'].astype('category').cat.codes
data['WeightClass_code'] = data['WeightClass'].astype('category').cat.codes

# %%
data
# Out:
#             RedFighter      BlueFighter  RedWins  RedLosses  \
# 0         Alex Pereira     Jamahal Hill        6          1
# 1          Zhang Weili      Yan Xiaonan        8          2
# 2       Justin Gaethje     Max Holloway        8          4
# 3     Charles Oliveira  Arman Tsarukyan       22          9
# 4            Bo Nickal    Cody Brundage        4          0
# ...                ...              ...      ...        ...
# 6183      Duane Ludwig    Darren Elkins        2          1
# 6184       John Howard   Daniel Roberts        3          0
# 6185    Brendan Schaub    Chase Gormley        0          1
# 6186       Mike Pierce    Julio Paulino        1          1
# 6187      Eric Schafer      Jason Brilz        3          3
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 0                       2         7           1                     4
# 1                       3         8           2                     2
# 2                       2        21           7                     2
# 3                       1         8           2                     3
# 4                       4         4           5                     2
# ...                   ...       ...         ...                   ...
# 6183                    0         0           0                     0
# 6184                    3         0           0                     0
# 6185                    0         0           1                     0
# 6186                    0         0           0                     0
# 6187                    0         2           1                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  RedWeightLbs  \
# 0                 5.2300               7.1800  ...           205
# 1                 5.6600               4.9700  ...           115
# 2                 6.7800               7.1700  ...           155
# 3                 3.3900               3.7900  ...           155
# 4                 1.6400               1.6200  ...           185
# ...                  ...                  ...  ...           ...
# 6183             13.6667                  NaN  ...           170
# 6184             18.0000                  NaN  ...           170
# 6185             12.0000               8.0000  ...           245
# 6186             40.5000                  NaN  ...           170
# 6187             15.6667              31.6667  ...           185
#
#       BlueWeightLbs RedReachCms BlueReachCms Winner  Date_code Location_code  \
# 0               205      200.66       200.66    Red        535            68
# 1               115      160.02       160.02    Red        535            68
# 2               145      177.80       175.26   Blue        535            68
# 3               155      187.96       182.88   Blue        535            68
# 4               185      193.04       182.88    Red        535            68
# ...             ...         ...          ...    ...        ...           ...
# 6183            145      177.80       180.34   Blue          0            26
# 6184            170      180.34       187.96    Red          0            26
# 6185            265      198.12       196.00    Red          0            26
# 6186            170      177.80       185.42    Red          0            26
# 6187            205      190.50       180.34   Blue          0            26
#
#       Country_code  TitleBout_code  WeightClass_code
# 0               31               1                 5
# 1               31               1                12
# 2               31               0                 6
# 3               31               0                 6
# 4               31               0                 7
# ...            ...             ...               ...
# 6183            21               0                 6
# 6184            21               0                 8
# 6185            21               0                 4
# 6186            21               0                 8
# 6187            21               0                 5
#
# [6188 rows x 37 columns]

# %%
data["target"] = (data["Winner"] == "Red").astype("int")

# %%
data
# Out:
#             RedFighter      BlueFighter  RedWins  RedLosses  \
# 0         Alex Pereira     Jamahal Hill        6          1
# 1          Zhang Weili      Yan Xiaonan        8          2
# 2       Justin Gaethje     Max Holloway        8          4
# 3     Charles Oliveira  Arman Tsarukyan       22          9
# 4            Bo Nickal    Cody Brundage        4          0
# ...                ...              ...      ...        ...
# 6183      Duane Ludwig    Darren Elkins        2          1
# 6184       John Howard   Daniel Roberts        3          0
# 6185    Brendan Schaub    Chase Gormley        0          1
# 6186       Mike Pierce    Julio Paulino        1          1
# 6187      Eric Schafer      Jason Brilz        3          3
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 0                       2         7           1                     4
# 1                       3         8           2                     2
# 2                       2        21           7                     2
# 3                       1         8           2                     3
# 4                       4         4           5                     2
# ...                   ...       ...         ...                   ...
# 6183                    0         0           0                     0
# 6184                    3         0           0                     0
# 6185                    0         0           1                     0
# 6186                    0         0           0                     0
# 6187                    0         2           1                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  BlueWeightLbs  \
# 0                 5.2300               7.1800  ...            205
# 1                 5.6600               4.9700  ...            115
# 2                 6.7800               7.1700  ...            145
# 3                 3.3900               3.7900  ...            155
# 4                 1.6400               1.6200  ...            185
# ...                  ...                  ...  ...            ...
# 6183             13.6667                  NaN  ...            145
# 6184             18.0000                  NaN  ...            170
# 6185             12.0000               8.0000  ...            265
# 6186             40.5000                  NaN  ...            170
# 6187             15.6667              31.6667  ...            205
#
#       RedReachCms BlueReachCms Winner Date_code  Location_code Country_code  \
# 0          200.66       200.66    Red       535             68           31
# 1          160.02       160.02    Red       535             68           31
# 2          177.80       175.26   Blue       535             68           31
# 3          187.96       182.88   Blue       535             68           31
# 4          193.04       182.88    Red       535             68           31
# ...           ...          ...    ...       ...            ...          ...
# 6183       177.80       180.34   Blue         0             26           21
# 6184       180.34       187.96    Red         0             26           21
# 6185       198.12       196.00    Red         0             26           21
# 6186       177.80       185.42    Red         0             26           21
# 6187       190.50       180.34   Blue         0             26           21
#
#       TitleBout_code  WeightClass_code  target
# 0                  1                 5       1
# 1                  1                12       1
# 2                  0                 6       0
# 3                  0                 6       0
# 4                  0                 7       1
# ...              ...               ...     ...
# 6183               0                 6       0
# 6184               0                 8       1
# 6185               0                 4       1
# 6186               0                 8       1
# 6187               0                 5       0
#
# [6188 rows x 38 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = data[data['Date'] < '2024-01-01']

# %%
test = data[data['Date'] > '2024-01-01']

# %%
predictors = ['RedWins', 'RedLosses', 'RedCurrentWinStreak',
              'BlueWins', 'BlueLosses', 'BlueCurrentWinStreak',
              'RedAvgSigStrLanded', 'BlueAvgSigStrLanded',
              'RedAvgTDLanded', 'BlueAvgTDLanded',
              'Date_code', 'Location_code', 'Country_code', 'TitleBout_code', 'WeightClass_code',
              'RedOdds', 'BlueOdds', 'RedExpectedValue', 'BlueExpectedValue',
              'RedDecOdds', 'BlueDecOdds', 'RKOOdds', 'BKOOdds',
              'RedHeightCms', 'BlueHeightCms', 'RedWeightLbs', 'BlueWeightLbs',
              'RedReachCms', 'BlueReachCms']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)

# %%
acc
# Out:
# 0.63125

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction   0   1
# actual
# 0           35  41
# 1           18  66

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], preds)
# Out:
# 0.616822429906542

# %%
grouped_data = data.groupby('RedFighter')

# %%
group = grouped_data.get_group('Max Holloway')

# %%
group
# Out:
#         RedFighter            BlueFighter  RedWins  RedLosses  \
# 303   Max Holloway         Chan Sung Jung       20          7
# 518   Max Holloway           Arnold Allen       19          7
# 1221  Max Holloway         Yair Rodriguez       18          6
# 1654  Max Holloway          Calvin Kattar       17          6
# 2129  Max Holloway  Alexander Volkanovski       17          4
# 2329  Max Holloway          Frankie Edgar       16          4
# 2485  Max Holloway         Dustin Poirier       16          3
# 2646  Max Holloway           Brian Ortega       15          3
# 3125  Max Holloway              Jose Aldo       14          3
# 3555  Max Holloway         Anthony Pettis       12          3
# 3835  Max Holloway          Ricardo Lamas       11          3
# 4032  Max Holloway        Jeremy Stephens       10          3
# 4152  Max Holloway       Charles Oliveira        9          3
# 4427  Max Holloway            Cole Miller        7          3
# 4656  Max Holloway           Clay Collard        5          3
# 4829  Max Holloway             Andre Fili        4          3
# 4968  Max Holloway             Will Chope        3          3
# 5544  Max Holloway          Pat Schilling        0          1
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 303                     1         7           6                     0
# 518                     0        10           0                    10
# 1221                    1         8           1                     2
# 1654                    0         6           2                     2
# 2129                    1         7           0                     7
# 2329                    0        17           6                     1
# 2485                   13        16           5                     3
# 2646                   12         6           1                     6
# 3125                   11         8           2                     0
# 3555                    9         6           4                     1
# 3835                    8         7           2                     1
# 4032                    7        11          10                     1
# 4152                    6         8           5                     4
# 4427                    4        10           6                     2
# 4656                    2         0           0                     0
# 4829                    1         1           0                     1
# 4968                    0         0           0                     0
# 5544                    0         0           1                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  BlueWeightLbs  \
# 303               7.1700               3.9300  ...            145
# 518               7.1700               3.4500  ...            145
# 1221              7.1700               4.6500  ...            145
# 1654              6.4700               5.0100  ...            145
# 2129                 NaN                  NaN  ...            145
# 2329              6.6600               3.6000  ...            145
# 2485             85.6316              52.3810  ...            155
# 2646             74.2778              35.5714  ...            145
# 3125             68.4118              56.4000  ...            145
# 3555             64.3333              31.2000  ...            170
# 3835             61.5714              27.3333  ...            145
# 4032             61.9231              33.6190  ...            145
# 4152             65.9167              25.3846  ...            155
# 4427             65.2000              30.7500  ...            145
# 4656             62.1250                  NaN  ...            145
# 4829             64.2857              55.0000  ...            145
# 4968             62.6667                  NaN  ...            145
# 5544             11.0000               4.0000  ...            145
#
#       RedReachCms BlueReachCms Winner Date_code  Location_code Country_code  \
# 303        175.26       182.88    Red       509             64           30
# 518        175.26       177.80    Red       491             65           31
# 1221       175.26       180.34    Red       433             68           31
# 1654       175.26       182.88    Red       395              0           32
# 2129       175.26       181.61   Blue       352             68           21
# 2329       175.26       172.72    Red       335             44            3
# 2485       175.26       182.88   Blue       322              6           21
# 2646       175.26       175.26    Red       309            139            3
# 3125       175.26       177.80    Red       269             40           21
# 3555       175.26       182.88    Red       231            139            3
# 3835       175.26       180.34    Red       208             73           21
# 4032       175.26       180.34    Red       192             68           21
# 4152       175.26       187.96    Red       181            127            3
# 4427       175.26       187.96    Red       157             26           21
# 4656       175.26       185.42    Red       137            140           21
# 4829       175.26       187.96    Red       124             11           21
# 4968       175.26       193.04    Red       111            132           18
# 5544       175.26       175.26    Red        59             68           21
#
#       TitleBout_code  WeightClass_code  target
# 303                0                 2       1
# 518                0                 2       1
# 1221               0                 2       1
# 1654               0                 2       1
# 2129               1                 2       0
# 2329               1                 2       1
# 2485               1                 6       0
# 2646               1                 2       1
# 3125               1                 2       1
# 3555               1                 2       1
# 3835               0                 2       1
# 4032               0                 2       1
# 4152               0                 2       1
# 4427               0                 2       1
# 4656               0                 1       1
# 4829               0                 2       1
# 4968               0                 2       1
# 5544               0                 2       1
#
# [18 rows x 38 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('Date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %% [markdown]
# # Calculating Rolling Averages for Columns
#
# ### Performance Metrics:
# * Red's average significant strikes landed
# * Blue's average significant strikes landed
# * Red's average takedowns landed
# * Blue's average takedowns landed
#
# ### Win/Loss Metrics:
# * Number of wins/losses for Red
# * Number of wins/losses for Blue
# * Current win streaks for Red/Blue
#
# ### Odds Metrics:
# * Red odds
# * Blue Odds
# * Red Expected Value
# * BlueExpectedValue

# %%
cols = ['RedAvgSigStrLanded', 'BlueAvgSigStrLanded', 'RedAvgTDLanded', 'BlueAvgTDLanded',
        'RedWins', 'RedLosses', 'BlueWins', 'BlueLosses', 'RedCurrentWinStreak', 'BlueCurrentWinStreak',
        'RedOdds', 'BlueOdds', 'RedExpectedValue', 'BlueExpectedValue', 'RKOOdds', 'BKOOdds']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['RedAvgSigStrLanded_rolling',
#  'BlueAvgSigStrLanded_rolling',
#  'RedAvgTDLanded_rolling',
#  'BlueAvgTDLanded_rolling',
#  'RedWins_rolling',
#  'RedLosses_rolling',
#  'BlueWins_rolling',
#  'BlueLosses_rolling',
#  'RedCurrentWinStreak_rolling',
#  'BlueCurrentWinStreak_rolling',
#  'RedOdds_rolling',
#  'BlueOdds_rolling',
#  'RedExpectedValue_rolling',
#  'BlueExpectedValue_rolling',
#  'RKOOdds_rolling',
#  'BKOOdds_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#         RedFighter            BlueFighter  RedWins  RedLosses  \
# 3835  Max Holloway          Ricardo Lamas       11          3
# 3555  Max Holloway         Anthony Pettis       12          3
# 3125  Max Holloway              Jose Aldo       14          3
# 2646  Max Holloway           Brian Ortega       15          3
# 2485  Max Holloway         Dustin Poirier       16          3
# 2329  Max Holloway          Frankie Edgar       16          4
# 2129  Max Holloway  Alexander Volkanovski       17          4
# 303   Max Holloway         Chan Sung Jung       20          7
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 3835                    8         7           2                     1
# 3555                    9         6           4                     1
# 3125                   11         8           2                     0
# 2646                   12         6           1                     6
# 2485                   13        16           5                     3
# 2329                    0        17           6                     1
# 2129                    1         7           0                     7
# 303                     1         7           6                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  BlueWins_rolling  \
# 3835             61.5714              27.3333  ...          9.666667
# 3555             64.3333              31.2000  ...          8.666667
# 3125             68.4118              56.4000  ...          8.000000
# 2646             74.2778              35.5714  ...          7.000000
# 2485             85.6316              52.3810  ...          6.666667
# 2329              6.6600               3.6000  ...         10.000000
# 2129                 NaN                  NaN  ...         13.000000
# 303               7.1700               3.9300  ...          8.000000
#
#       BlueLosses_rolling RedCurrentWinStreak_rolling  \
# 3835            7.000000                    5.666667
# 3555            5.666667                    7.000000
# 3125            5.333333                    8.000000
# 2646            2.666667                    9.333333
# 2485            2.333333                   10.666667
# 2329            2.666667                   12.000000
# 2129            4.000000                    8.333333
# 303             1.000000                    0.333333
#
#      BlueCurrentWinStreak_rolling RedOdds_rolling  BlueOdds_rolling  \
# 3835                     2.333333     -385.000000        325.000000
# 3555                     2.000000     -325.000000        268.333333
# 3125                     1.000000     -340.000000        280.000000
# 2646                     0.666667     -276.666667        233.333333
# 2485                     2.333333     -223.333333        120.000000
# 2329                     3.000000     -196.666667         96.666667
# 2129                     3.333333     -221.666667        115.000000
# 303                      4.666667     -336.333333        252.333333
#
#      RedExpectedValue_rolling  BlueExpectedValue_rolling  RKOOdds_rolling  \
# 3835                27.886700                 325.000000       170.000000
# 3555                32.824967                 268.333333       225.000000
# 3125                30.864167                 280.000000       273.333333
# 2646                36.277267                 233.333333       141.666667
# 2485                54.234633                 186.969700       163.333333
# 2329                58.275033                 163.636367       113.333333
# 2129                55.404767                 181.969700       200.000000
# 303                 44.894233                 252.333333       286.666667
#
#       BKOOdds_rolling
# 3835      1441.666667
# 3555      1091.666667
# 3125       841.666667
# 2646       750.000000
# 2485       483.333333
# 2329       391.666667
# 2129       645.000000
# 303        616.666667
#
# [8 rows x 54 columns]

# %%
data_rolling = data.groupby('RedFighter').apply(lambda x: rolling_averages(x, cols, new_cols))
data_rolling = data_rolling.droplevel('RedFighter')
# Out:
# /var/folders/75/zbxr0lm138b3wwbytdbpnrs80000gn/T/ipykernel_12172/2126673921.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data_rolling = data.groupby('RedFighter').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
data_rolling
# Out:
#                 RedFighter        BlueFighter  RedWins  RedLosses  \
# 1716  Abdul Razak Alhassan     Khaos Williams        4          2
# 1525  Abdul Razak Alhassan      Jacob Malkoun        4          3
# 931           Adrian Yanez        Tony Kelley        5          0
# 896         Aiemann Zahabi      Ricky Turcios        2          2
# 445         Aiemann Zahabi         Aoriqileng        3          2
# ...                    ...                ...      ...        ...
# 2665          Yushin Okami  Aleksei Kunchenko       14          6
# 4341          Yves Jabouin     Thomas Almeida        5          3
# 4159          Yves Jabouin     Felipe Arantes        5          4
# 2435          Zak Cummings       Trevin Giles        7          3
# 526           Zak Cummings          Ed Herman        9          5
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 1716                    0         1           0                     1
# 1525                    0         0           1                     0
# 931                     5         2           1                     2
# 896                     1         1           1                     1
# 445                     2         2           2                     2
# ...                   ...       ...         ...                   ...
# 2665                    1         1           0                     1
# 4341                    1         1           0                     1
# 4159                    0         3           4                     0
# 2435                    1         2           0                     2
# 526                     1        13          12                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  BlueWins_rolling  \
# 1716              4.5400              22.2200  ...          2.666667
# 1525              3.7100               1.7600  ...          1.666667
# 931               6.5100               5.5500  ...          1.000000
# 896               3.4300               4.6300  ...          0.666667
# 445               3.4300               5.3100  ...          0.666667
# ...                  ...                  ...  ...               ...
# 2665             25.1500              44.0000  ...          3.666667
# 4341             34.3750             120.0000  ...          1.666667
# 4159             32.7778              35.7143  ...          1.666667
# 2435             28.9000              55.5000  ...          3.666667
# 526               2.9600               3.3100  ...          3.666667
#
#       BlueLosses_rolling RedCurrentWinStreak_rolling  \
# 1716            1.666667                    2.000000
# 1525            0.666667                    1.666667
# 931             0.666667                    2.000000
# 896             0.666667                    0.666667
# 445             1.000000                    0.666667
# ...                  ...                         ...
# 2665            1.666667                    2.000000
# 4341            2.000000                    0.666667
# 4159            2.000000                    0.333333
# 2435            2.000000                    1.000000
# 526             1.000000                    1.333333
#
#      BlueCurrentWinStreak_rolling RedOdds_rolling  BlueOdds_rolling  \
# 1716                     1.000000     -243.333333        128.333333
# 1525                     1.000000     -231.666667        111.666667
# 931                      1.000000     -318.333333        243.000000
# 896                      0.333333       46.666667        -75.000000
# 445                      0.333333       56.666667        -88.333333
# ...                           ...             ...               ...
# 2665                     2.000000      166.666667       -181.666667
# 4341                     0.333333     -148.333333        121.666667
# 4159                     0.333333       65.000000       -110.000000
# 2435                     2.333333     -303.333333        246.666667
# 526                      3.000000     -190.000000        130.000000
#
#      RedExpectedValue_rolling  BlueExpectedValue_rolling  RKOOdds_rolling  \
# 1716                52.086067                 195.303033       -78.333333
# 1525                53.853767                 178.636367      -100.000000
# 931                 36.059433                 243.000000       -48.333333
# 896                124.047633                  86.754400       826.000000
# 445                134.047633                  83.703300       672.666667
# ...                       ...                        ...              ...
# 2665               166.666667                  60.144933      1158.333333
# 4341                87.399567                 210.151500       423.333333
# 4159               188.137267                 126.421333       826.666667
# 2435                43.212300                 246.666667       370.000000
# 526                 80.271133                 213.333333       609.333333
#
#       BKOOdds_rolling
# 1716       410.000000
# 1525       335.000000
# 931        658.333333
# 896        605.000000
# 445        476.333333
# ...               ...
# 2665       165.333333
# 4341      1018.333333
# 4159       490.000000
# 2435      1005.000000
# 526        867.333333
#
# [1317 rows x 54 columns]

# %%
data_rolling.index = range(data_rolling.shape[0])

# %%
data_rolling
# Out:
#                 RedFighter        BlueFighter  RedWins  RedLosses  \
# 0     Abdul Razak Alhassan     Khaos Williams        4          2
# 1     Abdul Razak Alhassan      Jacob Malkoun        4          3
# 2             Adrian Yanez        Tony Kelley        5          0
# 3           Aiemann Zahabi      Ricky Turcios        2          2
# 4           Aiemann Zahabi         Aoriqileng        3          2
# ...                    ...                ...      ...        ...
# 1312          Yushin Okami  Aleksei Kunchenko       14          6
# 1313          Yves Jabouin     Thomas Almeida        5          3
# 1314          Yves Jabouin     Felipe Arantes        5          4
# 1315          Zak Cummings       Trevin Giles        7          3
# 1316          Zak Cummings          Ed Herman        9          5
#
#       RedCurrentWinStreak  BlueWins  BlueLosses  BlueCurrentWinStreak  \
# 0                       0         1           0                     1
# 1                       0         0           1                     0
# 2                       5         2           1                     2
# 3                       1         1           1                     1
# 4                       2         2           2                     2
# ...                   ...       ...         ...                   ...
# 1312                    1         1           0                     1
# 1313                    1         1           0                     1
# 1314                    0         3           4                     0
# 1315                    1         2           0                     2
# 1316                    1        13          12                     0
#
#       RedAvgSigStrLanded  BlueAvgSigStrLanded  ...  BlueWins_rolling  \
# 0                 4.5400              22.2200  ...          2.666667
# 1                 3.7100               1.7600  ...          1.666667
# 2                 6.5100               5.5500  ...          1.000000
# 3                 3.4300               4.6300  ...          0.666667
# 4                 3.4300               5.3100  ...          0.666667
# ...                  ...                  ...  ...               ...
# 1312             25.1500              44.0000  ...          3.666667
# 1313             34.3750             120.0000  ...          1.666667
# 1314             32.7778              35.7143  ...          1.666667
# 1315             28.9000              55.5000  ...          3.666667
# 1316              2.9600               3.3100  ...          3.666667
#
#       BlueLosses_rolling RedCurrentWinStreak_rolling  \
# 0               1.666667                    2.000000
# 1               0.666667                    1.666667
# 2               0.666667                    2.000000
# 3               0.666667                    0.666667
# 4               1.000000                    0.666667
# ...                  ...                         ...
# 1312            1.666667                    2.000000
# 1313            2.000000                    0.666667
# 1314            2.000000                    0.333333
# 1315            2.000000                    1.000000
# 1316            1.000000                    1.333333
#
#      BlueCurrentWinStreak_rolling RedOdds_rolling  BlueOdds_rolling  \
# 0                        1.000000     -243.333333        128.333333
# 1                        1.000000     -231.666667        111.666667
# 2                        1.000000     -318.333333        243.000000
# 3                        0.333333       46.666667        -75.000000
# 4                        0.333333       56.666667        -88.333333
# ...                           ...             ...               ...
# 1312                     2.000000      166.666667       -181.666667
# 1313                     0.333333     -148.333333        121.666667
# 1314                     0.333333       65.000000       -110.000000
# 1315                     2.333333     -303.333333        246.666667
# 1316                     3.000000     -190.000000        130.000000
#
#      RedExpectedValue_rolling  BlueExpectedValue_rolling  RKOOdds_rolling  \
# 0                   52.086067                 195.303033       -78.333333
# 1                   53.853767                 178.636367      -100.000000
# 2                   36.059433                 243.000000       -48.333333
# 3                  124.047633                  86.754400       826.000000
# 4                  134.047633                  83.703300       672.666667
# ...                       ...                        ...              ...
# 1312               166.666667                  60.144933      1158.333333
# 1313                87.399567                 210.151500       423.333333
# 1314               188.137267                 126.421333       826.666667
# 1315                43.212300                 246.666667       370.000000
# 1316                80.271133                 213.333333       609.333333
#
#       BKOOdds_rolling
# 0          410.000000
# 1          335.000000
# 2          658.333333
# 3          605.000000
# 4          476.333333
# ...               ...
# 1312       165.333333
# 1313      1018.333333
# 1314       490.000000
# 1315      1005.000000
# 1316       867.333333
#
# [1317 rows x 54 columns]

# %%
def make_predictions(data, predictors):
    train = data[data['Date'] < '2024-01-01']
    test = data[data['Date'] > '2024-01-01']
    rf.fit(train[predictors], train['target'])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], predicted=preds), index=test.index)
    precision = precision_score(test['target'], preds)
    return combined, precision

# %%
combined, precision = make_predictions(data_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.7333333333333333
